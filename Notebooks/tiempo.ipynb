# %%
import pandas as pd
import json

# %%
# Ruta del archivo JSON
ruta_json = r'..\Raw_Datasets\Trabajado\tiempo.json'

# Leer el contenido del archivo JSON
with open(ruta_json, 'r') as file:
    json_data = json.load(file)

# Obtener la lista de datos desde el campo "list" del JSON
data_list = json_data['data']['list']

# Crear un DataFrame de pandas desde la lista de datos
data = pd.DataFrame(data_list)

# Mostrar el DataFrame
data
# Out:
#             dt                                               main  \
# 0   1690459200  {'temp': 297.84, 'feels_like': 297.3, 'temp_mi...
# 1   1690470000  {'temp': 300.59, 'feels_like': 299.63, 'temp_m...
# 2   1690480800  {'temp': 301.66, 'feels_like': 300.16, 'temp_m...
# 3   1690491600  {'temp': 293.79, 'feels_like': 292.61, 'temp_m...
# 4   1690502400  {'temp': 291.23, 'feels_like': 290.16, 'temp_m...
# 5   1690513200  {'temp': 289.05, 'feels_like': 288.05, 'temp_m...
# 6   1690524000  {'temp': 290.06, 'feels_like': 289.14, 'temp_m...
# 7   1690534800  {'temp': 297.46, 'feels_like': 296.73, 'temp_m...
# 8   1690545600  {'temp': 301.8, 'feels_like': 300.33, 'temp_mi...
# 9   1690556400  {'temp': 303.78, 'feels_like': 301.79, 'temp_m...
# 10  1690567200  {'temp': 302.07, 'feels_like': 300.49, 'temp_m...
# 11  1690578000  {'temp': 294.39, 'feels_like': 293.3, 'temp_mi...
# 12  1690588800  {'temp': 292.43, 'feels_like': 291.54, 'temp_m...
# 13  1690599600  {'temp': 289.65, 'feels_like': 289.13, 'temp_m...
# 14  1690610400  {'temp': 289.97, 'feels_like': 289.59, 'temp_m...
# 15  1690621200  {'temp': 297.43, 'feels_like': 297.01, 'temp_m...
# 16  1690632000  {'temp': 302.36, 'feels_like': 300.99, 'temp_m...
# 17  1690642800  {'temp': 304.32, 'feels_like': 302.47, 'temp_m...
# 18  1690653600  {'temp': 302.48, 'feels_like': 300.96, 'temp_m...
# 19  1690664400  {'temp': 294.58, 'feels_like': 293.64, 'temp_m...
# 20  1690675200  {'temp': 292.65, 'feels_like': 291.73, 'temp_m...
# 21  1690686000  {'temp': 290.68, 'feels_like': 289.82, 'temp_m...
# 22  1690696800  {'temp': 290.67, 'feels_like': 289.89, 'temp_m...
# 23  1690707600  {'temp': 298.78, 'feels_like': 298.23, 'temp_m...
# 24  1690718400  {'temp': 303.49, 'feels_like': 301.74, 'temp_m...
# 25  1690729200  {'temp': 305.43, 'feels_like': 303.29, 'temp_m...
# 26  1690740000  {'temp': 303.25, 'feels_like': 301.5, 'temp_mi...
# 27  1690750800  {'temp': 294.96, 'feels_like': 294.08, 'temp_m...
# 28  1690761600  {'temp': 293.24, 'feels_like': 292.45, 'temp_m...
# 29  1690772400  {'temp': 291.94, 'feels_like': 291, 'temp_min'...
# 30  1690783200  {'temp': 291.69, 'feels_like': 290.8, 'temp_mi...
# 31  1690794000  {'temp': 299.41, 'feels_like': 299.41, 'temp_m...
# 32  1690804800  {'temp': 303.75, 'feels_like': 301.88, 'temp_m...
# 33  1690815600  {'temp': 305.09, 'feels_like': 302.92, 'temp_m...
# 34  1690826400  {'temp': 303.08, 'feels_like': 301.26, 'temp_m...
# 35  1690837200  {'temp': 294.73, 'feels_like': 293.62, 'temp_m...
# 36  1690848000  {'temp': 292.8, 'feels_like': 291.66, 'temp_mi...
# 37  1690858800  {'temp': 292.15, 'feels_like': 290.94, 'temp_m...
# 38  1690869600  {'temp': 292.65, 'feels_like': 291.47, 'temp_m...
# 39  1690880400  {'temp': 300.59, 'feels_like': 299.52, 'temp_m...
#
#                                               weather       clouds  \
# 0   [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 1   [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 9}
# 2   [{'id': 801, 'main': 'Clouds', 'description': ...  {'all': 21}
# 3   [{'id': 801, 'main': 'Clouds', 'description': ...  {'all': 15}
# 4   [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 7}
# 5   [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 6   [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 4}
# 7   [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 1}
# 8   [{'id': 801, 'main': 'Clouds', 'description': ...  {'all': 18}
# 9   [{'id': 802, 'main': 'Clouds', 'description': ...  {'all': 33}
# 10  [{'id': 801, 'main': 'Clouds', 'description': ...  {'all': 16}
# 11  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 12  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 13  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 14  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 15  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 16  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 17  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 18  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 5}
# 19  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 4}
# 20  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 2}
# 21  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 22  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 23  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 24  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 25  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 26  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 27  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 28  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 29  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 30  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 31  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 32  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 33  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 34  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 35  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 36  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 37  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 38  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
# 39  [{'id': 800, 'main': 'Clear', 'description': '...   {'all': 0}
#
#                                          wind  visibility  pop           sys  \
# 0   {'speed': 5.57, 'deg': 194, 'gust': 6.52}       10000    0  {'pod': 'd'}
# 1   {'speed': 4.33, 'deg': 208, 'gust': 7.08}       10000    0  {'pod': 'd'}
# 2   {'speed': 5.18, 'deg': 270, 'gust': 6.83}       10000    0  {'pod': 'd'}
# 3   {'speed': 2.29, 'deg': 254, 'gust': 2.84}       10000    0  {'pod': 'n'}
# 4   {'speed': 2.38, 'deg': 283, 'gust': 3.45}       10000    0  {'pod': 'n'}
# 5   {'speed': 1.43, 'deg': 266, 'gust': 2.19}       10000    0  {'pod': 'n'}
# 6    {'speed': 0.77, 'deg': 237, 'gust': 1.3}       10000    0  {'pod': 'd'}
# 7   {'speed': 1.59, 'deg': 198, 'gust': 3.33}       10000    0  {'pod': 'd'}
# 8   {'speed': 2.65, 'deg': 231, 'gust': 4.55}       10000    0  {'pod': 'd'}
# 9   {'speed': 3.09, 'deg': 256, 'gust': 4.85}       10000    0  {'pod': 'd'}
# 10  {'speed': 3.28, 'deg': 278, 'gust': 4.13}       10000    0  {'pod': 'd'}
# 11  {'speed': 1.46, 'deg': 290, 'gust': 2.11}       10000    0  {'pod': 'n'}
# 12  {'speed': 2.51, 'deg': 292, 'gust': 2.78}       10000    0  {'pod': 'n'}
# 13  {'speed': 1.36, 'deg': 279, 'gust': 2.13}       10000    0  {'pod': 'n'}
# 14  {'speed': 1.17, 'deg': 296, 'gust': 1.52}       10000    0  {'pod': 'd'}
# 15  {'speed': 1.53, 'deg': 269, 'gust': 2.51}       10000    0  {'pod': 'd'}
# 16  {'speed': 2.72, 'deg': 258, 'gust': 5.33}       10000    0  {'pod': 'd'}
# 17  {'speed': 3.23, 'deg': 264, 'gust': 5.02}       10000    0  {'pod': 'd'}
# 18  {'speed': 5.27, 'deg': 298, 'gust': 4.89}       10000    0  {'pod': 'd'}
# 19  {'speed': 1.96, 'deg': 302, 'gust': 2.87}       10000    0  {'pod': 'n'}
# 20  {'speed': 1.89, 'deg': 291, 'gust': 2.25}       10000    0  {'pod': 'n'}
