# %%
import pandas as pd
import numpy as np

# %%
piscina = pd.read_csv('../Raw_Datasets/Trabajado/210227-0-piscinas-publicas.csv',sep=';',encoding='latin-1')

# %%
piscina
# Out:
#           PK                                             NOMBRE  \
# 0       4707  Centro Deportivo Municipal  María Jesús Rosa (...
# 1   10183549               Centro Deportivo Municipal Alcántara
# 2     114782       Centro Deportivo Municipal Alfredo Goyeneche
# 3       4696                  Centro Deportivo Municipal Aluche
# 4       4678  Centro Deportivo Municipal Ángel Nieto (antigu...
# 5    4624404     Centro Deportivo Municipal Antonio Díaz Miguel
# 6      99578                 Centro Deportivo Municipal Barajas
# 7       4695  Centro Deportivo Municipal Blanca Fernández Oc...
# 8       4705           Centro Deportivo Municipal Casa de Campo
# 9   12022187            Centro Deportivo Municipal Cea Bermúdez
# 10     78960  Centro Deportivo Municipal Centro Integrado Ar...
# 11      4687         Centro Deportivo Municipal Cerro Almodóvar
# 12      4700               Centro Deportivo Municipal Chamartín
# 13      4672              Centro Deportivo Municipal Concepción
# ...

# %%
piscina.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PK                   59 non-null     int64
#  1   NOMBRE               59 non-null     object
#  2   DESCRIPCION-ENTIDAD  0 non-null      float64
#  3   HORARIO              58 non-null     object
#  4   EQUIPAMIENTO         57 non-null     object
#  5   TRANSPORTE           59 non-null     object
#  6   DESCRIPCION          7 non-null      object
#  7   ACCESIBILIDAD        59 non-null     object
#  8   CONTENT-URL          59 non-null     object
#  9   NOMBRE-VIA           59 non-null     object
#  10  CLASE-VIAL           59 non-null     object
#  11  TIPO-NUM             59 non-null     object
#  12  NUM                  58 non-null     float64
#  13  PLANTA               0 non-null      float64
#  14  PUERTA               0 non-null      float64
# ...

# %%
piscina= piscina.drop(columns=['PLANTA','PUERTA','ESCALERAS','ORIENTACION','DESCRIPCION-ENTIDAD','DESCRIPCION'])

# %%
piscina['EQUIPAMIENTO'].fillna('No disponible', inplace=True)

# %%
piscina['HORARIO'].fillna('Horario no disponible', inplace=True)

# %%
# piscina['COD-BARRIO'].fillna(method='ffill', inplace=True)

# %%
# piscina['COD-DISTRITO'].fillna(method='ffill', inplace=True)

# %%
piscina = piscina.drop(columns=['Unnamed: 32','FAX'])

# %%
piscina = piscina.drop(columns=['COD-DISTRITO','COD-BARRIO'])

# %%
piscina['EMAIL'].fillna('No disponible', inplace=True)

# %% [markdown]
# piscina

# %%
barrio_mapping = piscina.groupby('NUM')['BARRIO'].first()

# %%
barrio_mapping
# Out:
# NUM
# 1.0                  ALMENARA
# 2.0              NUEVA ESPAÑA
# 3.0                  ARAPILES
# 4.0                 ENTREVIAS
# 5.0                CONCEPCION
# 6.0                VALDEZARZA
# 7.0           PALOMERAS BAJAS
# 8.0              PUEBLO NUEVO
# 9.0             SANTA EUGENIA
# 11.0     CIUDAD UNIVERSITARIA
# 12.0     CIUDAD UNIVERSITARIA
# 13.0                 JUSTICIA
# 14.0              LAS AGUILAS
# 15.0                  PALACIO
# 17.0          PALOS DE MOGUER
# 18.0               SAN FERMIN
# 19.0              LOS ROSALES
# 20.0                 CANILLAS
# 22.0            CASA DE CAMPO
# 25.0                  ACACIAS
# 26.0                     GOYA
# 30.0                  PALOMAS
# 33.0            CIUDAD JARDIN
# 36.0         FUENTE DEL BERRO
# 38.0                 EL PILAR
# 41.0             VISTA ALEGRE
# 47.0                   HELLIN
# 51.0          PALOMERAS BAJAS
# 52.0                    ZOFIO
# 68.0                    REJAS
# 70.0         ALAMEDA DE OSUNA
# ...

# %%
piscina.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PK             59 non-null     int64
#  1   NOMBRE         59 non-null     object
#  2   HORARIO        59 non-null     object
#  3   EQUIPAMIENTO   59 non-null     object
#  4   TRANSPORTE     59 non-null     object
#  5   ACCESIBILIDAD  59 non-null     object
#  6   CONTENT-URL    59 non-null     object
#  7   NOMBRE-VIA     59 non-null     object
#  8   CLASE-VIAL     59 non-null     object
#  9   TIPO-NUM       59 non-null     object
#  10  NUM            58 non-null     float64
#  11  LOCALIDAD      59 non-null     object
#  12  PROVINCIA      59 non-null     object
#  13  CODIGO-POSTAL  59 non-null     int64
#  14  COD-BARRIO     57 non-null     float64
#  15  BARRIO         59 non-null     object
#  16  COD-DISTRITO   57 non-null     float64
# ...

# %%
piscina
# Out:
#           PK                                             NOMBRE  \
# 0       4707  Centro Deportivo Municipal  María Jesús Rosa (...
# 1   10183549               Centro Deportivo Municipal Alcántara
# 2     114782       Centro Deportivo Municipal Alfredo Goyeneche
# 3       4696                  Centro Deportivo Municipal Aluche
# 4       4678  Centro Deportivo Municipal Ángel Nieto (antigu...
# 5    4624404     Centro Deportivo Municipal Antonio Díaz Miguel
# 6      99578                 Centro Deportivo Municipal Barajas
# 7       4695  Centro Deportivo Municipal Blanca Fernández Oc...
# 8       4705           Centro Deportivo Municipal Casa de Campo
# 9   12022187            Centro Deportivo Municipal Cea Bermúdez
# 10     78960  Centro Deportivo Municipal Centro Integrado Ar...
# 11      4687         Centro Deportivo Municipal Cerro Almodóvar
# 12      4700               Centro Deportivo Municipal Chamartín
# 13      4672              Centro Deportivo Municipal Concepción
# ...

# %%
ruta_archivo_csv = '../Raw_Datasets/Trabajado/Piscinas_publicas.csv'
piscina.to_csv(ruta_archivo_csv, index=False)
