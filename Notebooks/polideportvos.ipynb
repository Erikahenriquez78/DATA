# %%
import numpy as np
import pandas as pd

# %%
polis = pd.read_csv('../Raw_Datasets/Trabajado/200186-0-polideportivos.csv', sep=';',encoding='latin-1')

# %%
polis.describe()
# Out:
#                  PK         NUM  PUERTA  ESCALERAS  CODIGO-POSTAL  COD-BARRIO  \
# count  7.900000e+01   78.000000     0.0        0.0      79.000000   75.000000
# mean   1.934066e+06   32.243590     NaN        NaN   28026.759494    3.373333
# std    3.322173e+06   60.996101     NaN        NaN      14.994200    1.880004
# min    4.672000e+03    1.000000     NaN        NaN   28002.000000    1.000000
# 25%    4.693500e+03    5.000000     NaN        NaN   28011.000000    2.000000
# 50%    4.727000e+03   11.000000     NaN        NaN   28029.000000    3.000000
# 75%    4.581261e+06   32.250000     NaN        NaN   28041.000000    5.000000
# max    1.182013e+07  376.000000     NaN        NaN   28054.000000    7.000000
#
#        COD-DISTRITO   COORDENADA-X  COORDENADA-Y    LATITUD   LONGITUD
# count     75.000000      79.000000  7.900000e+01  79.000000  79.000000
# mean      10.466667  442121.962025  4.474247e+06  40.416704  -3.682297
# ...

# %%
polis
# Out:
#           PK                                             NOMBRE  \
# 0       4707  Centro Deportivo Municipal  María Jesús Rosa (...
# 1   10183549               Centro Deportivo Municipal Alcántara
# 2     114782       Centro Deportivo Municipal Alfredo Goyeneche
# 3       4696                  Centro Deportivo Municipal Aluche
# 4    4617960       Centro Deportivo Municipal Antiguo Canódromo
# ..       ...                                                ...
# 74      4678  Centro Deportivo Municipal Ángel Nieto (antigu...
# 75  10663007            Estadio Vallehermoso (centro deportivo)
# 76   4541767  Instalación Deportiva Municipal Básica Parque ...
# 77   6210334  Instalación Deportiva Municipal Básica Torresp...
# 78   4544562  Instalación Deportiva Municipal Básica Victori...
#
#                                   DESCRIPCION-ENTIDAD  \
# 0                                                 NaN
# 1                                                 NaN
# ...

# %%
polis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PK                   79 non-null     int64
#  1   NOMBRE               79 non-null     object
#  2   DESCRIPCION-ENTIDAD  1 non-null      object
#  3   HORARIO              76 non-null     object
#  4   EQUIPAMIENTO         75 non-null     object
#  5   TRANSPORTE           79 non-null     object
#  6   DESCRIPCION          10 non-null     object
#  7   ACCESIBILIDAD        79 non-null     object
#  8   CONTENT-URL          79 non-null     object
#  9   NOMBRE-VIA           79 non-null     object
#  10  CLASE-VIAL           79 non-null     object
#  11  TIPO-NUM             79 non-null     object
#  12  NUM                  78 non-null     float64
#  13  PLANTA               1 non-null      object
#  14  PUERTA               0 non-null      float64
# ...

# %%
eliminar = ['ESCALERAS','PUERTA','PLANTA','ORIENTACION','DESCRIPCION-ENTIDAD']
eliminar
# Out:
# ['ESCALERAS', 'PUERTA', 'PLANTA', 'ORIENTACION', 'DESCRIPCION-ENTIDAD']

# %%
polis = polis.drop(columns=eliminar)

# %%
eliminar2 = 'DESCRIPCION'
polis = polis.drop(columns=eliminar2)

# %%
polis
# Out:
#           PK                                             NOMBRE  \
# 0       4707  Centro Deportivo Municipal  María Jesús Rosa (...
# 1   10183549               Centro Deportivo Municipal Alcántara
# 2     114782       Centro Deportivo Municipal Alfredo Goyeneche
# 3       4696                  Centro Deportivo Municipal Aluche
# 4    4617960       Centro Deportivo Municipal Antiguo Canódromo
# ..       ...                                                ...
# 74      4678  Centro Deportivo Municipal Ángel Nieto (antigu...
# 75  10663007            Estadio Vallehermoso (centro deportivo)
# 76   4541767  Instalación Deportiva Municipal Básica Parque ...
# 77   6210334  Instalación Deportiva Municipal Básica Torresp...
# 78   4544562  Instalación Deportiva Municipal Básica Victori...
#
#                                               HORARIO  \
# 0   Horario de uso de las instalaciones deportivas...
# 1   Horario de uso de las instalaciones deportivas...
# ...

# %%
polis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PK             79 non-null     int64
#  1   NOMBRE         79 non-null     object
#  2   HORARIO        76 non-null     object
#  3   EQUIPAMIENTO   75 non-null     object
#  4   TRANSPORTE     79 non-null     object
#  5   ACCESIBILIDAD  79 non-null     object
#  6   CONTENT-URL    79 non-null     object
#  7   NOMBRE-VIA     79 non-null     object
#  8   CLASE-VIAL     79 non-null     object
#  9   TIPO-NUM       79 non-null     object
#  10  NUM            78 non-null     float64
#  11  LOCALIDAD      79 non-null     object
#  12  PROVINCIA      78 non-null     object
#  13  CODIGO-POSTAL  79 non-null     int64
#  14  COD-BARRIO     75 non-null     float64
#  15  BARRIO         79 non-null     object
#  16  COD-DISTRITO   75 non-null     float64
# ...

# %%
mean_num = polis['NUM'].mean()
polis['NUM'].fillna(mean_num, inplace=True)

# %%
polis = polis.fillna(0)

# %%
polis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79 entries, 0 to 78
# Data columns (total 27 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PK             79 non-null     int64
#  1   NOMBRE         79 non-null     object
#  2   HORARIO        79 non-null     object
#  3   EQUIPAMIENTO   79 non-null     object
#  4   TRANSPORTE     79 non-null     object
#  5   ACCESIBILIDAD  79 non-null     object
#  6   CONTENT-URL    79 non-null     object
#  7   NOMBRE-VIA     79 non-null     object
#  8   CLASE-VIAL     79 non-null     object
#  9   TIPO-NUM       79 non-null     object
#  10  NUM            79 non-null     float64
#  11  LOCALIDAD      79 non-null     object
#  12  PROVINCIA      79 non-null     object
#  13  CODIGO-POSTAL  79 non-null     int64
#  14  COD-BARRIO     79 non-null     float64
#  15  BARRIO         79 non-null     object
#  16  COD-DISTRITO   79 non-null     float64
# ...

# %%
polis
# Out:
#           PK                                             NOMBRE  \
# 0       4707  Centro Deportivo Municipal  María Jesús Rosa (...
# 1   10183549               Centro Deportivo Municipal Alcántara
# 2     114782       Centro Deportivo Municipal Alfredo Goyeneche
# 3       4696                  Centro Deportivo Municipal Aluche
# 4    4617960       Centro Deportivo Municipal Antiguo Canódromo
# ..       ...                                                ...
# 74      4678  Centro Deportivo Municipal Ángel Nieto (antigu...
# 75  10663007            Estadio Vallehermoso (centro deportivo)
# 76   4541767  Instalación Deportiva Municipal Básica Parque ...
# 77   6210334  Instalación Deportiva Municipal Básica Torresp...
# 78   4544562  Instalación Deportiva Municipal Básica Victori...
#
#                                               HORARIO  \
# 0   Horario de uso de las instalaciones deportivas...
# 1   Horario de uso de las instalaciones deportivas...
# ...

# %%
ruta_archivo_csv = '../Raw_Datasets/Trabajado/Polideportivos.csv'

# %%
polis.to_csv(ruta_archivo_csv, index=False)
