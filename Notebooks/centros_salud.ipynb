# %%
import pandas as pd

# %%
centros = pd.read_csv('../Centros_de_salud_de_Madrid.csv', sep=',')
centros
# Out:
#             X          Y  FID  OID_                                 TIPOCEN2  \
# 0   -3.365999  40.481648    1     2           Centro de Salud Carmen Calzado
# 1   -3.350480  40.487732    2     8          Centro de Salud Juan de Austria
# 2   -3.393029  40.481640    3     9                Centro de Salud La Garena
# 3   -3.368122  40.475056    4     6        Centro de Salud Luis Vives I y II
# 4   -3.357354  40.482162    5     5            Centro de Salud Manuel Merino
# ..        ...        ...  ...   ...                                      ...
# 261 -3.685277  40.192128  262   260                Centro de Salud Valdemoro
# 262 -4.300194  40.274539  263   262          Centro de Salud Villa del Prado
# 263 -4.001834  40.446805  264   263  Centro de Salud Villanueva de la Caaada
# 264 -3.275264  40.170269  265   264    Centro de Salud Villarejo de Salvanas
# 265 -3.908264  40.359110  266   265     Centro de Salud Villaviciosa de Odnn
#
#     TIPOVIAL                   NOMVIA  NUMERO                MUNICIPIO  \
# 0      Calle           Carmen Calzado      14        Alcal1 de Henares
# 1    Avenida          Juan de Austria      19        Alcal1 de Henares
# 2      Calle             Arturo Soria      10        Alcal1 de Henares
# 3      Calle               Luis Vives      16        Alcal1 de Henares
# 4      Calle            Manuel Merino       1        Alcal  de Henares
# ..       ...                      ...     ...                      ...
# 261    Calle                    Parla      14                Valdemoro
# 262    Paseo           de la Estaciln       2          Villa del Prado
# 263    Calle  de las Eras de MVstoles      18  Villanueva de la Caoada
# 264    Calle                 Hospital       7    Villarejo de Salvanls
# 265  Avenida     Principe de Asturias     173     Villaviciosa de Odan
#
#      CODMUN   UTM_X    UTM_Y
# 0         5  468979  4481282
# 1         5  470297  4481952
# 2         5  466688  4481291
# 3         5  468796  4480551
# 4         5  469712  4481336
# ..      ...     ...      ...
# 261     161  441669  4449307
# 262     171  389460  4459040
# 263     176  415043  4477832
# 264     180  476562  4446692
# 265     181  422878  4468012
#
# [266 rows x 12 columns]

# %%
centros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   X          266 non-null    float64
#  1   Y          266 non-null    float64
#  2   FID        266 non-null    int64
#  3   OID_       266 non-null    int64
#  4   TIPOCEN2   266 non-null    object
#  5   TIPOVIAL   266 non-null    object
#  6   NOMVIA     266 non-null    object
#  7   NUMERO     266 non-null    int64
#  8   MUNICIPIO  266 non-null    object
#  9   CODMUN     266 non-null    int64
#  10  UTM_X      266 non-null    int64
#  11  UTM_Y      266 non-null    int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 25.1+ KB

# %%
centros = centros.drop(columns=['FID','OID_','UTM_X','UTM_Y','CODMUN'])

# %%
ruta_archivo_csv = '../Raw_Datasets/Trabajado/centros_de_salud.csv'
centros.to_csv(ruta_archivo_csv, index=False)
