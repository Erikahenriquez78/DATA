# %%
import pandas as pd

# %%
centros = pd.read_csv('../Raw_Datasets/Trabajado/Centros_de_salud.csv', sep=',')
centros
# Out:
#             X   Longitud                                 TIPOCEN2 TIPOVIAL  \
# 0   -3.365999  40.481648           Centro de Salud Carmen Calzado    Calle
# 1   -3.350480  40.487732          Centro de Salud Juan de Austria  Avenida
# 2   -3.393029  40.481640                Centro de Salud La Garena    Calle
# 3   -3.368122  40.475056        Centro de Salud Luis Vives I y II    Calle
# 4   -3.357354  40.482162            Centro de Salud Manuel Merino    Calle
# ..        ...        ...                                      ...      ...
# 261 -3.685277  40.192128                Centro de Salud Valdemoro    Calle
# 262 -4.300194  40.274539          Centro de Salud Villa del Prado    Paseo
# 263 -4.001834  40.446805  Centro de Salud Villanueva de la Caaada    Calle
# 264 -3.275264  40.170269    Centro de Salud Villarejo de Salvanas    Calle
# 265 -3.908264  40.359110     Centro de Salud Villaviciosa de Odnn  Avenida
#
#                    DIRECCION  NUM                 MUNICIPIO
# ...

# %%
centros.iloc[229]
# Out:
# X                                    -3.351696
# Longitud                             40.231687
# TIPOCEN2     Centro de Salud Perales de Taju a
# TIPOVIAL                               Avenida
# DIRECCION                                  Paz
# NUM                                          5
# MUNICIPIO                    Perales de Tajuña
# Name: 229, dtype: object

# %%
print(centros['MUNICIPIO'].iloc[240:267])
# Out:
# 240        San Fernando de Henares
# 241        San Fernando de Henares
# 242     San Lorenzo de El Escorial
# 243          San Martín de la Vega
# 244    San Martln de Valdeiglesias
# 245     San Sebastian de los Reyes
# 246     San Sebastian de los Reyes
# 247     San Sebastian de los Reyes
# 248                  Soto del Real
# 249              Torrejón de Ardoz
# 250              Torrejón de Ardoz
# 251              Torrejón de Ardoz
# 252              Torrejón de Ardoz
# 253              Torrejón de Ardoz
# 254              Torrejón de Ardoz
# 255                    Torrelaguna
# 256                   Torrelodones
# 257           Torres de la Alameda
# 258                    Tres Cantos
# 259                    Tres Cantos
# 260                      Valdemoro
# 261                      Valdemoro
# 262                Villa del Prado
# 263        Villanueva de la Cañada
# 264          Villarejo de Salvanés
# 265           Villaviciosa de Odín
# Name: MUNICIPIO, dtype: object

# %%
centros['MUNICIPIO'] = centros['MUNICIPIO'].replace({
    'Alcal1 de Henares': 'Alcalá de Henares',
    'Alcal de Henares ': 'Alcalá de Henares',
    'Alcal2 de Henares': 'Alcalá de Henares',
    'Alcal4 de Henares': 'Alcalá de Henares',
    'Alcal6 de Henares': 'Alcalá de Henares',
     'Alcorc2n': 'Alcorcón',
    'Alcorc8n': 'Alcorcón',
    'Alcorc1n': 'Alcorcón',
    'Alcorc0n': 'Alcorcón',
    'Alcorc5n': 'Alcorcón',
    'Alcorc7n': 'Alcorcón',
    'Gri  n' :'Griñon',
    'Legan s' :'Leganés',
    'Legan3s':'Leganés',
    'Legan1s':'Leganés',
    'M stoles':'Mostoles',
    'Perales de Taju a':' Perales de Tajuña',
    'Pozuelo de Alarcrn': 'Pozuelo de Alarcón',
    'Pozuelo de AlarcPn': 'Pozuelo de Alarcón',
    'Pozuelo de AlarcSn': 'Pozuelo de Alarcón',
    'Rascafr': 'Rascafria',
   'San MartOn de la Vega':'San Martín de la Vega',
    'Torrej0n de Ardoz':'Torrejón de Ardoz',
    'Torrej4n de Ardoz':'Torrejón de Ardoz',
    'Torrej9n de Ardoz':'Torrejón de Ardoz',
    'Torrej4n de Ardoz':'Torrejón de Ardoz',
    'Torrej7n de Ardoz':'Torrejón de Ardoz',
    'Torrej0n de Ardoz':'Torrejón de Ardoz',
    'Villanueva de la Caoada': ' Villanueva de la Cañada',
    'Villarejo de Salvanls':'Villarejo de Salvanés',
    'Villaviciosa de Odan': 'Villaviciosa de Odín',
    
    
})

# %%
centros
# Out:
#             X   Longitud                                 TIPOCEN2 TIPOVIAL  \
# 0   -3.365999  40.481648           Centro de Salud Carmen Calzado    Calle
# 1   -3.350480  40.487732          Centro de Salud Juan de Austria  Avenida
# 2   -3.393029  40.481640                Centro de Salud La Garena    Calle
# 3   -3.368122  40.475056        Centro de Salud Luis Vives I y II    Calle
# 4   -3.357354  40.482162            Centro de Salud Manuel Merino    Calle
# ..        ...        ...                                      ...      ...
# 261 -3.685277  40.192128                Centro de Salud Valdemoro    Calle
# 262 -4.300194  40.274539          Centro de Salud Villa del Prado    Paseo
# 263 -4.001834  40.446805  Centro de Salud Villanueva de la Caaada    Calle
# 264 -3.275264  40.170269    Centro de Salud Villarejo de Salvanas    Calle
# 265 -3.908264  40.359110     Centro de Salud Villaviciosa de Odnn  Avenida
#
#                    DIRECCION  NUM                 MUNICIPIO
# ...

# %%
# centros = centros.drop(columns=['FID','OID_','UTM_X','UTM_Y','CODMUN'])

# %%
# Cambiar el nombre de la columna "ColumnaAntigua1" a "NuevaColumna1"
centros.rename(columns={'X': 'LATITUD'}, inplace=True)
centros.rename(columns={'Longitud': 'LONGITUD'}, inplace=True)
centros.rename(columns={'NUMERO': 'NUM'}, inplace=True)
centros.rename(columns={'NOMVIA': 'DIRECCION'}, inplace=True)

# %%
centros
# Out:
#       LATITUD   LONGITUD                                 TIPOCEN2 TIPOVIAL  \
# 0   -3.365999  40.481648           Centro de Salud Carmen Calzado    Calle
# 1   -3.350480  40.487732          Centro de Salud Juan de Austria  Avenida
# 2   -3.393029  40.481640                Centro de Salud La Garena    Calle
# 3   -3.368122  40.475056        Centro de Salud Luis Vives I y II    Calle
# 4   -3.357354  40.482162            Centro de Salud Manuel Merino    Calle
# ..        ...        ...                                      ...      ...
# 261 -3.685277  40.192128                Centro de Salud Valdemoro    Calle
# 262 -4.300194  40.274539          Centro de Salud Villa del Prado    Paseo
# 263 -4.001834  40.446805  Centro de Salud Villanueva de la Caaada    Calle
# 264 -3.275264  40.170269    Centro de Salud Villarejo de Salvanas    Calle
# 265 -3.908264  40.359110     Centro de Salud Villaviciosa de Odnn  Avenida
#
#                    DIRECCION  NUM                 MUNICIPIO
# ...

# %%
ruta_archivo_csv = '../Raw_Datasets/Trabajado/centros_de_salud.csv'
centros.to_csv(ruta_archivo_csv, index=False)
